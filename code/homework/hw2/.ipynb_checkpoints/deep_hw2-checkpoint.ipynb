# %% [markdown]
# # Deep Learning study toy Project 1

# %% [markdown]
# 백준 문제중에 Linear Algebra and Group 이라는 문제가 있다.
#
# 아주 단순한 문제로 "선형대수와 군"(이인석, 개정판)의 사진에 있는 모든 그림의 숫자를 합하면 되는 문제다.
#
# 자세한 문제는 [이곳을 참고하자](https://www.acmicpc.net/problem/15636)
#
#
#
# > 문제를 확인했다면 ["선형대수와 군" 책의 사진을 보자](http://image.aladin.co.kr/product/5972/77/letslook/8952117441_f.jpg)
#
# 이 문제를 풀기 위해 고민하던 우리는 딥러닝 스터디에서 MNIST를 배운 기억을 떠올렸다.
#
# MNIST를 활용해서 문제를 풀어보자

# %% [markdown]
# > 참고로 지금부터 코드는 파이썬 3.6를 권장한다.<br>
# > 만일 주피터 노트북의 파이썬이 3.6버전이 아니라면<br>
# > conda install python=3.6 명령어를 이용하여 버전을 변경시키자

# %% [markdown]
# # Problem 1
#
# ### 이미지 가져오기
#
# 우리는 선형대수와 군 책을 가지고 있지않다. 따라서 이미지를 가져와야 하는데 마우스 오른쪽 클릭하여 이미지를 가져오기엔 체면이 살지 않는다. <br>
# 웹 스크래핑 실습때 배운 이미지 추출을 복습할겸 한번 가볍게 써보자
#
# 참고로 이미지를 가져올 주소는 http://image.aladin.co.kr/product/5972/77/letslook/8952117441_f.jpg 를 이용하면 된다.
#
# 이미지는 images 폴더 내부에 linear.jpg 라는 파일명으로 만들자.
#
# ##### 참고: urllib 함수는 파이썬 내장함수이다. 별로도 설치할 필요 없다.

# %%
from urllib.request import urlretrieve
import os

# 만일 images 폴더가 존재하지 않으면 해당 폴더를 만든다.
if not os.path.isdir('images'):
    os.mkdir('images')

# insert your code
# Out:
# ('./images/linear.jpg', <http.client.HTTPMessage at 0x1d58ff77080>)

# %% [markdown]
# ### 이미지 실행시키기
#
# 이미지가 제대로 가져와졌는지 실행시켜보자.<br>
# 이미지를 실행시키기 위해 PIL이라는 모듈을 사용하겠다. PIL은 이미지를 가공하기 좋은 모듈이다.
#
# ##### 만일 아래 코드가 실행이 되지 않는다면 다음 명령어로 모듈을 설치하기 바란다.<br>
# > conda install PIL

# %%
from PIL import Image
import PIL.ImageOps

img = Image.open("./images/linear.jpg")
img.show()

# %% [markdown]
# 이미지가 정상적으로 나왔다면 성공적으로 가져온 것이다. 이제 모든 준비가 끝났다.

# %% [markdown]
# # Problem 2
#
# ### Image Cropping
#
# #### EXAMPLE
# 이미지를 가져왔다면 이제 알맞은 크기로 잘라야 한다.<br>
# 우선 간단한 예제로 이미지를 잘라보자.

# %%
# 우선 이미지를 가져온다.
img = Image.open("./images/linear.jpg") 

# 자를 이미지의 좌상단과 우하단의 (x1, y2, x2, y2) 좌표로 bounding box를 만든다.
# 위치를 모를 경우 그림판이나 다른 툴을 이용하면 좌표를 알 수 있다.
# 아래 좌표는 예시이다.
area = (30, 34, 871, 745)

# 선택한 좌표를 가지고 crop 함수를 이용해 자른다.
cropped_img = img.crop(area)

#자른 이미지를 확인해본다.
cropped_img.show()

#자른 이미지를 저장한다.
path = './images/'
name = 'test'
cropped_img.save(path + name + '.png')

# %% [markdown]
# <br><br><br>
#
#
#
# 실행해보면 우리가 계산할 숫자들의 이미지가 나올 것 이다.<br>
# 하지만 우리가 원하는 사진은 숫자 하나 하나 잘라야 한다.
#
# 다음 사진을 보자
# <img src="./pic/01.PNG" width=80%/>
#
# ### 우선 위 사진 처럼 사진을 하나씩 잘라보자. 파일의 형식은 0001.png 과 같은 형식이다.
#
# #### 참고로 사진은 총  1450개 이다. 즉, 0001.png 부터 1450.png가 나와야 한다.

# %%
# insert your code

# %% [markdown]
# 실행 후 사진이 잘 나왔는지 확인해 보자.

# %% [markdown]
# # Problem 3
#
# ### image preprocessing
#
# 우리가 자른 이미지는 MNIST에 의해 훈련된 모델로 분류가 잘 될까?<br>
# 거의 분류가 되지 않을 것이다. 아니 그 전에 실행이 되지 않을것이다.
#
# 우리가 자른 이미지의 사이즈는(자르기에 따라 약간의 오차가 있겠지만)
#  대략 (17, 24, 3)의 픽셀로 이루어져 있다. 각각 width, height, depth의 값이다.
#
# 하지만 MNIST의 데이터는 (28, 28, 1)로 사이즈가 서로 다르다.
#
# 또한 이미지 주변의 테두리도 잘라내고 싶다.
#
# 다음 순서로 이미지를 가공해보자.
#
# > 1. 위와 마찬가지로 이미지를 일단 자른다.
# 2. 테두리의 검은 선을 자르기 위해 자른 이미지를 다시 한번 약간 자른다.
# 3. Image 모듈의 함수를 이용해서 28X28의 이미지로 scaling 시킨다.
# 4. depth를 1로 만들기 위해 사진을 흑백으로 변경시킨다. 이 때 convert 함수를 이용한다.
# 5. MNIST는 배경이 검은색 글씨가 흰색인 사진이다. 우리의 사진도 마찬가지로 만들어주기 위해 사진의 색을 반전시키자.
#
# [모듈에 관한 자세한 설명은 이곳을 참고하자](https://pillow.readthedocs.io/en/3.1.x/reference/Image.html)
#
#
#
# 실행 결과는 다음과 같다<br><br>
# <img src="./pic/02.PNG" width=80%/>

# %%
# insert your code
# 코드가 완성됐다면 함수로 만들어서 계속 사용 할 수 있게 하자
# 함수의 이름은 image_prep() 로 하 도록 하자.

# %% [markdown]
# # Problem 4
#
# ### softmax로 MNIST 학습시키기
#
# lab 7에서 혹은 이후 lab에서 실습한 예제를 이용해서 MNIST를 학습시키자.

# %%
# MNIST를 학습시켜보자. 복붙하지 말자
# Out:
# Extracting MNIST_DATA/train-images-idx3-ubyte.gz
# Extracting MNIST_DATA/train-labels-idx1-ubyte.gz
# Extracting MNIST_DATA/t10k-images-idx3-ubyte.gz
# Extracting MNIST_DATA/t10k-labels-idx1-ubyte.gz
# Epoch: 0001 cost = 2.716091383
# Epoch: 0002 cost = 1.125968439
# Epoch: 0003 cost = 0.893897345
# Epoch: 0004 cost = 0.779650599
# Epoch: 0005 cost = 0.706707907
# Epoch: 0006 cost = 0.655683602
# Epoch: 0007 cost = 0.616128033
# Epoch: 0008 cost = 0.584717756
# Epoch: 0009 cost = 0.560021318
# Epoch: 0010 cost = 0.538587356
# Epoch: 0011 cost = 0.520472809
# Epoch: 0012 cost = 0.504906741
# Epoch: 0013 cost = 0.490552664
# Epoch: 0014 cost = 0.478469964
# Epoch: 0015 cost = 0.467234628
# Accuracy:  0.8896

# %% [markdown]
# 간단한 모델을 이용하다 보니 정확도가 높지 않다.<br>
#
# 하지만 그대로 진행한다. 대략 88%이상의 정확도면 된다.

# %% [markdown]
# # Problem 5
#
# ### 이미지 데이터 가져오기
#
# 이미지의 리스트를 가져오기 위해서 glob 라는 함수를 사용하자

# %%
import glob

# 파일이 존재하는 폴더의 위치를 정해주고 
# 해당 위치의 모든 png file을 정렬해서 가져온다.





# 이후 test_data list에 해당 이미지를 open하여 append한다.

# %% [markdown]
# 하나의 테스트 파일을 출력해 보자.
# size가 28X28이면 알맞게 불러진 것이다.

# %%
print(test_data[0])
print(len(test_data))
# Out:
# <PIL.Image.Image image mode=L size=28x28 at 0x1D59B4D4DD8>
# 1450

# %% [markdown]
# 불러온 데이터를 하나 열어보자

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.imshow(np.array(test_data[10]), cmap="Greys",interpolation='nearest')
plt.show()

# %% [markdown]
# # Problem 6
#
# ### 이미지 테스트 해보기
#
# 이미지를 테스트 해 보는 단계이다.
#
# 훈련한 모델을 이용하여 모델이 제대로 분류를 하는지 확인해 보자.
#
# 확인을 하기 위해 사진이 들어있는 폴더 내에 0부터 9까지의 폴더를 만들어야 한다.
#
# 그리고 사진을 예측한 값의 이름을 가진 폴더에 넣게 된다.
#
#
# > 폴더 조작을 위해 shutil 모듈을 이용해 보자

# %%
import numpy as np
import shutil


# 폴더가 존재하지 않다면 폴더를 만들자





# 학습한 모델을 가지고 예측을 해보자. 예측후 해당 폴더로 파일을 이동시킨다.
# Out:
# ./data\0001.png
# ./data/9/
# [9]
# ./data\0002.png
# ./data/0/
# [0]
# ./data\0003.png
# ./data/1/
# [1]
# ./data\0004.png
# ./data/6/
# [6]
# ./data\0005.png
# ./data/6/
# [6]
# ./data\0006.png
# ./data/6/
# [6]
# ./data\0007.png
# ./data/0/
# [0]
# ./data\0008.png
# ./data/7/
# [7]
# ./data\0009.png
# ./data/4/
# [4]
# ./data\0010.png
# ./data/6/
# [6]
# ./data\0011.png
# ./data/7/
# [7]
# ./data\0012.png
# ./data/6/
# [6]
# ./data\0013.png
# ./data/6/
# [6]
# ./data\0014.png
# ./data/0/
# [0]
# ./data\0015.png
# ./data/0/
# [0]
# ./data\0016.png
# ./data/0/
# [0]
# ./data\0017.png
# ./data/6/
# [6]
# ./data\0018.png
# ./data/4/
# [4]
# ./data\0019.png
# ./data/6/
# [6]
# ./data\0020.png
# ./data/7/
# [7]
# ./data\0021.png
# ./data/8/
# [8]
# ./data\0022.png
# ./data/7/
# [7]
# ./data\0023.png
# ./data/6/
# [6]
# ./data\0024.png
# ./data/6/
# [6]
# ./data\0025.png
# ./data/7/
# [7]
# ./data\0026.png
# ./data/0/
# [0]
# ./data\0027.png
# ./data/5/
# [5]
# ./data\0028.png
# ./data/0/
# [0]
# ./data\0029.png
# ./data/0/
# [0]
# ./data\0030.png
# ./data/0/
# [0]
# ./data\0031.png
# ./data/3/
# [3]
# ./data\0032.png
# ./data/0/
# [0]
# ./data\0033.png
# ./data/8/
# [8]
# ./data\0034.png
# ./data/7/
# [7]
# ./data\0035.png
# ./data/4/
# [4]
# ./data\0036.png
# ./data/6/
# [6]
# ./data\0037.png
# ./data/0/
# [0]
# ./data\0038.png
# ./data/6/
# [6]
# ./data\0039.png
# ./data/6/
# [6]
# ./data\0040.png
# ./data/6/
# [6]
# ./data\0041.png
# ./data/0/
# [0]
# ./data\0042.png
# ./data/8/
# [8]
# ./data\0043.png
# ./data/7/
# [7]
# ./data\0044.png
# ./data/9/
# [9]
# ./data\0045.png
# ./data/0/
# [0]
# ./data\0046.png
# ./data/6/
# [6]
# ./data\0047.png
# ./data/0/
# [0]
# ./data\0048.png
# ./data/8/
# [8]
# ./data\0049.png
# ./data/7/
# [7]
# ./data\0050.png
# ./data/8/
# [8]
# ./data\0051.png
# ./data/9/
# [9]
# ./data\0052.png
# ./data/9/
# [9]
# ./data\0053.png
# ./data/9/
# [9]
# ./data\0054.png
# ./data/9/
# [9]
# ./data\0055.png
# ./data/0/
# [0]
# ./data\0056.png
# ./data/9/
# [9]
# ./data\0057.png
# ./data/8/
# [8]
# ./data\0058.png
# ./data/8/
# [8]
# ./data\0059.png
# ./data/9/
# [9]
# ./data\0060.png
# ./data/9/
# [9]
# ./data\0061.png
# ./data/2/
# [2]
# ./data\0062.png
# ./data/3/
# [3]
# ./data\0063.png
# ./data/8/
# [8]
# ./data\0064.png
# ./data/2/
# [2]
# ./data\0065.png
# ./data/9/
# [9]
# ./data\0066.png
# ./data/8/
# [8]
# ./data\0067.png
# ./data/9/
# [9]
# ./data\0068.png
# ./data/9/
# [9]
# ./data\0069.png
# ./data/9/
# [9]
# ./data\0070.png
# ./data/0/
# [0]
# ./data\0071.png
# ./data/8/
# [8]
# ./data\0072.png
# ./data/2/
# [2]
# ./data\0073.png
# ./data/9/
# [9]
# ./data\0074.png
# ./data/9/
# [9]
# ./data\0075.png
# ./data/9/
# [9]
# ./data\0076.png
# ./data/9/
# [9]
# ./data\0077.png
# ./data/9/
# [9]
# ./data\0078.png
# ./data/9/
# [9]
# ./data\0079.png
# ./data/8/
# [8]
# ./data\0080.png
# ./data/9/
# [9]
# ./data\0081.png
# ./data/0/
# [0]
# ./data\0082.png
# ./data/0/
# [0]
# ./data\0083.png
# ./data/9/
# [9]
# ./data\0084.png
# ./data/0/
# [0]
# ./data\0085.png
# ./data/9/
# [9]
# ./data\0086.png
# ./data/3/
# [3]
# ./data\0087.png
# ./data/8/
# [8]
# ./data\0088.png
# ./data/8/
# [8]
# ./data\0089.png
# ./data/0/
# [0]
# ./data\0090.png
# ./data/9/
# [9]
# ./data\0091.png
# ./data/8/
# [8]
# ./data\0092.png
# ./data/8/
# [8]
# ./data\0093.png
# ./data/0/
# [0]
# ./data\0094.png
# ./data/9/
# [9]
# ./data\0095.png
# ./data/9/
# [9]
# ./data\0096.png
# ./data/9/
# [9]
# ./data\0097.png
# ./data/0/
# [0]
# ./data\0098.png
# ./data/0/
# [0]
# ./data\0099.png
# ./data/2/
# [2]
# ./data\0100.png
# ./data/8/
# [8]
# ./data\0101.png
# ./data/9/
# [9]
# ./data\0102.png
# ./data/0/
# [0]
# ./data\0103.png
# ./data/9/
# [9]
# ./data\0104.png
# ./data/6/
# [6]
# ./data\0105.png
# ./data/6/
# [6]
# ./data\0106.png
# ./data/7/
# [7]
# ./data\0107.png
# ./data/6/
# [6]
# ./data\0108.png
# ./data/4/
# [4]
# ./data\0109.png
# ./data/0/
# [0]
# ./data\0110.png
# ./data/8/
# [8]
# ./data\0111.png
# ./data/7/
# [7]
# ./data\0112.png
# ./data/0/
# [0]
# ./data\0113.png
# ./data/9/
# [9]
# ./data\0114.png
# ./data/4/
# [4]
# ./data\0115.png
# ./data/0/
# [0]
# ./data\0116.png
# ./data/6/
# [6]
# ./data\0117.png
# ./data/6/
# [6]
# ./data\0118.png
# ./data/7/
# [7]
# ./data\0119.png
# ./data/0/
# [0]
# ./data\0120.png
# ./data/1/
# [1]
# ./data\0121.png
# ./data/8/
# [8]
# ./data\0122.png
# ./data/6/
# [6]
# ./data\0123.png
# ./data/3/
# [3]
# ./data\0124.png
# ./data/6/
# [6]
# ./data\0125.png
# ./data/6/
# [6]
# ./data\0126.png
# ./data/6/
# [6]
# ./data\0127.png
# ./data/5/
# [5]
# ./data\0128.png
# ./data/0/
# [0]
# ./data\0129.png
# ./data/0/
# [0]
# ./data\0130.png
# ./data/0/
# [0]
# ./data\0131.png
# ./data/3/
# [3]
# ./data\0132.png
# ./data/6/
# [6]
# ./data\0133.png
# ./data/6/
# [6]
# ./data\0134.png
# ./data/4/
# [4]
# ./data\0135.png
# ./data/6/
# [6]
# ./data\0136.png
# ./data/0/
# [0]
# ./data\0137.png
# ./data/8/
# [8]
# ./data\0138.png
# ./data/6/
# [6]
# ./data\0139.png
# ./data/6/
# [6]
# ./data\0140.png
# ./data/0/
# [0]
# ./data\0141.png
# ./data/7/
# [7]
# ./data\0142.png
# ./data/0/
# [0]
# ./data\0143.png
# ./data/0/
# [0]
# ./data\0144.png
# ./data/6/
# [6]
# ./data\0145.png
# ./data/6/
# [6]
# ./data\0146.png
# ./data/4/
# [4]
# ./data\0147.png
# ./data/3/
# [3]
# ./data\0148.png
# ./data/3/
# [3]
# ./data\0149.png
# ./data/6/
# [6]
# ./data\0150.png
# ./data/6/
# [6]
# ./data\0151.png
# ./data/4/
# [4]
# ./data\0152.png
# ./data/8/
# [8]
# ./data\0153.png
# ./data/9/
# [9]
# ./data\0154.png
# ./data/8/
# [8]
# ./data\0155.png
# ./data/9/
# [9]
# ./data\0156.png
# ./data/0/
# [0]
# ./data\0157.png
# ./data/9/
# [9]
# ./data\0158.png
# ./data/3/
# [3]
# ./data\0159.png
# ./data/8/
# [8]
# ./data\0160.png
# ./data/6/
# [6]
# ./data\0161.png
# ./data/3/
# [3]
# ./data\0162.png
# ./data/9/
# [9]
# ./data\0163.png
# ./data/6/
# [6]
# ./data\0164.png
# ./data/9/
# [9]
# ./data\0165.png
# ./data/0/
# [0]
# ./data\0166.png
# ./data/8/
# [8]
# ./data\0167.png
# ./data/9/
# [9]
# ./data\0168.png
# ./data/6/
# [6]
# ./data\0169.png
# ./data/9/
# [9]
# ./data\0170.png
# ./data/0/
# [0]
# ./data\0171.png
# ./data/7/
# [7]
# ./data\0172.png
# ./data/0/
# [0]
# ./data\0173.png
# ./data/0/
# [0]
# ./data\0174.png
# ./data/3/
# [3]
# ./data\0175.png
# ./data/3/
# [3]
# ./data\0176.png
# ./data/9/
# [9]
# ./data\0177.png
# ./data/6/
# [6]
# ./data\0178.png
# ./data/9/
# [9]
# ./data\0179.png
# ./data/6/
# [6]
# ./data\0180.png
# ./data/9/
# [9]
# ./data\0181.png
# ./data/8/
# [8]
# ./data\0182.png
# ./data/6/
# [6]
# ./data\0183.png
# ./data/3/
# [3]
# ./data\0184.png
# ./data/9/
# [9]
# ./data\0185.png
# ./data/9/
# [9]
# ./data\0186.png
# ./data/0/
# [0]
# ./data\0187.png
# ./data/0/
# [0]
# ./data\0188.png
# ./data/3/
# [3]
# ./data\0189.png
# ./data/0/
# [0]
# ./data\0190.png
# ./data/0/
# [0]
# ./data\0191.png
# ./data/8/
# [8]
# ./data\0192.png
# ./data/8/
# [8]
# ./data\0193.png
# ./data/8/
# [8]
# ./data\0194.png
# ./data/8/
# [8]
# ./data\0195.png
# ./data/9/
# [9]
# ./data\0196.png
# ./data/6/
# [6]
# ./data\0197.png
# ./data/8/
# [8]
# ./data\0198.png
# ./data/0/
# [0]
# ./data\0199.png
# ./data/0/
# [0]
# ./data\0200.png
# ./data/6/
# [6]
# [1038]

# %% [markdown]
# 사진이 폴더에 들어가면 테스트에 성공한 것이다.
#
# 이제 폴더를 열어 결과를 확인해 보자.
#
# 결과가 잘 나왔으면 어떠한 기법을 사용한 것인지 잘 나오지 못하였다면 어떤 부분에서 문제가 생긴지 생각해 보자
#
# 개선 할 수 있다면 개선하여 도전해보자

# %% [markdown]
# # Problem 7
#
# ### 초기화 하기
#
#
# 테스트가 끝난 뒤 다시 테스트를 하려면 손이 많이 간다.
#
# 이러한 점이 불편하게 느껴지니 자동으로 초기 상태로 돌려주는 프로그램을 만들고자 한다.
#
# 우선 아쉽게도 shutil 모듈 내부에는 모든 파일을 지우는 함수가 없다.
#
# 따라서 shutil의 모듈의 폴더를 지우는 함수를 이용하여 폴더를 지우고 해당 폴더를 다시 만드는 작업을 하자
#
# 그리고 위에서 만든 imag_prep() 함수를 이용하여 없어진 사진도 다시 복구하자
#
# 모두 다 끝난 뒤 init() 함수로 만들면 된다.

# %%
import os
import shutil
